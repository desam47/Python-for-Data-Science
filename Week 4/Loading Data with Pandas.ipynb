# %%
import pandas
csv_path='test.csv'
df=pandas.read_csv(csv_path)
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0.42.19
# 1            AC/DC              Back in Black      1980  0.42.20
# 2       Pink Floyd  The Dark Side of the Moon      1973  0.42.21
# 3  Whitney Houston              The Bodyguard      1992  0.42.22
# 4        Meat Loaf           Ball Out of Hell      1977  0.42.23
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtracks  Rating
# 0                        65   11/30/82         NaN    10.0
# 1                        50   12/01/82         NaN     9.5
# ...

# %%
import pandas as pd
csv_path='test.csv'
df=pd.read_csv(csv_path)
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0.42.19
# 1            AC/DC              Back in Black      1980  0.42.20
# 2       Pink Floyd  The Dark Side of the Moon      1973  0.42.21
# 3  Whitney Houston              The Bodyguard      1992  0.42.22
# 4        Meat Loaf           Ball Out of Hell      1977  0.42.23
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtracks  Rating
# 0                        65   11/30/82         NaN    10.0
# 1                        50   12/01/82         NaN     9.5
# ...

# %%
#creating Dataframe

import pandas as pd
songs = {'Album' :['Thriller','Back in Black','The Dark Side of the Moon','The Bodyguard','Ball Out of Hell','Their Greatest Hits (1971-1975)','Saturday Night Fever','Rumours'],
        'Released':[1982,1980,1973,1992,1977,1976,1977,1977],
        'Length':['0.42.19','0.42.20','0.42.21','0.42.22','0.42.23','0.42.24','0.42.25','0.42.26']}
songs_frame=pd.DataFrame(songs)
songs_frame.head()
# Out:
#                        Album  Released   Length
# 0                   Thriller      1982  0.42.19
# 1              Back in Black      1980  0.42.20
# 2  The Dark Side of the Moon      1973  0.42.21
# 3              The Bodyguard      1992  0.42.22
# 4           Ball Out of Hell      1977  0.42.23

# %%
#creating dataframe from preexesting dataframe
x=df[['Artist','Length']]
x.head()
# Out:
#             Artist   Length
# 0  Michael Jackson  0.42.19
# 1            AC/DC  0.42.20
# 2       Pink Floyd  0.42.21
# 3  Whitney Houston  0.42.22
# 4        Meat Loaf  0.42.23

# %%
#selecting data from dataframe
#loc is label based
df.loc[0,'Artist']
# Out:
# 'Michael Jackson'

# %%
#selecting data from dataframe
#iloc is integer based
df.iloc[0,0]
# Out:
# 'Michael Jackson'

# %%
#slicing
#loc

z=df.loc[0:4,'Artist':'Released']
z.head()
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973
# 3  Whitney Houston              The Bodyguard      1992
# 4        Meat Loaf           Ball Out of Hell      1977

# %%
#slicing
#iloc

z=df.iloc[0:4,0:3]
z.head()
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973
# 3  Whitney Houston              The Bodyguard      1992
